# %%
import pandas as pd
from FlightTracker import FlightTracker
from rnog_data.runtable import RunTable


tracker = FlightTracker('2022-05-01 00:00:00', '2022-11-01 00:00:00')

# %%
tracker.flights_distinct
# Out:
#       index flightnumber        date              filename  \
# 0      2143     CSN8064   2022-05-01  2022.05.01-044301.db
# 1      2144          N/A  2022-05-01  2022.05.01-044301.db
# 2      3607          N/A  2022-05-01  2022.05.02-044306.db
# 3      2146     RCH496    2022-05-01  2022.05.01-044301.db
# 4      3606     JAL41     2022-05-01  2022.05.02-044306.db
# ...     ...          ...         ...                   ...
# 5425   2138     SAS935    2022-10-31  2022.11.01-035830.db
# 5426   2139     DLH458    2022-10-31  2022.11.01-035830.db
# 5427   2140     KLM219    2022-10-31  2022.11.01-035830.db
# 5428   2142     ANA203    2022-10-31  2022.11.01-035830.db
# 5429   3563     ANA203    2022-10-31  2022.10.31-035825.db
#
#                          mintime                     maxtime  min_r  min_z  \
# 0     2022-05-01 01:23:22.600000  2022-05-01 01:38:06.900000   72.9    8.3
# 1     2022-05-01 01:39:32.300000  2022-05-01 03:09:03.400000   93.3    8.3
# ...

# %%
runs = pd.DataFrame({'station' : [], 'run' : []})
rnog_table = RunTable()
length = len(tracker.flights_distinct)
for i in range(length):
    mintime = tracker.flights_distinct.mintime.iloc[i]
    maxtime = tracker.flights_distinct.maxtime.iloc[i]
    df = pd.DataFrame()
    runtable = rnog_table.get_table(start_time=mintime, stop_time=maxtime)

    if len(runtable) != 0:
        df = pd.DataFrame({'station' : list(runtable.station), 'run' : list(runtable.run)})
        runs = pd.concat([runs, df], ignore_index=True, sort=False)
    print(i, 'of', length)
runs
# Out:
# INFO:runtable_database:database connection to RNOG_live established
# 0 of 5430
# 1 of 5430
# 2 of 5430
# 3 of 5430
# 4 of 5430
# 5 of 5430
# 6 of 5430
# 7 of 5430
# 8 of 5430
# 9 of 5430
# 10 of 5430
# 11 of 5430
# 12 of 5430
# 13 of 5430
# 14 of 5430
# 15 of 5430
# 16 of 5430
# 17 of 5430
# 18 of 5430
# 19 of 5430
# 20 of 5430
# 21 of 5430
# 22 of 5430
# 23 of 5430
# 24 of 5430
# 25 of 5430
# 26 of 5430
# 27 of 5430
# 28 of 5430
# 29 of 5430
# 30 of 5430
# 31 of 5430
# 32 of 5430
# 33 of 5430
# 34 of 5430
# 35 of 5430
# 36 of 5430
# 37 of 5430
# 38 of 5430
# 39 of 5430
# 40 of 5430
# 41 of 5430
# 42 of 5430
# 43 of 5430
# 44 of 5430
# 45 of 5430
# 46 of 5430
# 47 of 5430
# 48 of 5430
# 49 of 5430
# 50 of 5430
# 51 of 5430
# 52 of 5430
# 53 of 5430
# 54 of 5430
# 55 of 5430
# 56 of 5430
# 57 of 5430
# 58 of 5430
# 59 of 5430
# 60 of 5430
# 61 of 5430
# 62 of 5430
# 63 of 5430
# 64 of 5430
# 65 of 5430
# 66 of 5430
# 67 of 5430
# 68 of 5430
# 69 of 5430
# 70 of 5430
# 71 of 5430
# ...

# %%
runs.drop_duplicates(inplace = True)
runs.dropna(inplace = True)

runs['station'] = runs.station.astype(int)
runs['run'] = runs.run.astype(int)

# %%
runs = runs.sort_values(by = ['station', 'run'])

# %%
runs
# Out:
#        station   run
# 4825        11  1001
# 4826        11  1002
# 4827        11  1003
# 4828        11  1004
# 4829        11  1005
# ...        ...   ...
# 25955       24   903
# 26485       24   918
# 26486       24   919
# 26505       24   920
# 26537       24   928
#
# [5738 rows x 2 columns]

# %%
import pandas as pd
runs_old = pd.read_csv('runs.csv', delimiter='\t')
runs_old.sort_values(by = ['station', 'run'])
runs_old.drop_duplicates(inplace=True)
runs_old
# Out:
#      station   run
# 0         21  1002
# 1         21  1004
# 2         21  1005
# 3         21  1007
# 4         21  1010
# ..       ...   ...
# 693       12   319
# 694       11  1065
# 695       12   320
# 696       11  1066
# 697       12   321
#
# [591 rows x 2 columns]

# %%
combined = pd.concat([runs, runs_old], ignore_index=True)
# Drop those rows from df1

runs_filtered = combined.drop_duplicates(keep=False)
runs_filtered
# Out:
#       station   run
# 4          11  1005
# 35         11  1051
# 51         11  1067
# 52         11  1068
# 53         11  1069
# ...       ...   ...
# 5733       24   903
# 5734       24   918
# 5735       24   919
# 5736       24   920
# 5737       24   928
#
# [5147 rows x 2 columns]

# %%
runs_filtered.to_csv('runs_filtered.csv', index=False)

# %%
# testing something

runs[(runs.station == 12) & runs.run == 93]
# Out:
# Empty DataFrame
# Columns: [station, run]
# Index: []
