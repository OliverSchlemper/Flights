# %%
import pytz
import os
import sqlite3
import re
import uproot
import IPython
import sys
import copy
import numpy as np
import pandas as pd
import pymap3d as pm
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from pandasql import sqldf
from rnog_data.runtable import RunTable
from datetime import datetime, timedelta
from matplotlib.ticker import MaxNLocator
from scipy.fft import fft
from scipy.signal import stft
from NuRadioReco.modules.io.RNO_G.readRNOGDataMattak import readRNOGData
from NuRadioReco.utilities import units
from Flight import Flight
from IPython.display import clear_output


pd.options.display.float_format = '{:20,.15f}'.format
#-------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------
from FlightTracker import FlightTracker

current_month = '04'
next_month = '08'

start_time=f'2023-{current_month}-01 00:00:00'
stop_time=f'2023-{next_month}-01 00:00:00'

#start_time=f'2023-01-01 00:00:00'
#stop_time=f'2024-01-01 00:00:00'

tracker_initial = FlightTracker(start_time, stop_time, destination='./flights/flights_2023.db', already_calculated=True)
tracker = copy.deepcopy(tracker_initial) # make a new instance of the tracker
print(len(tracker.flights), len(tracker.flights_distinct))
tracker.flights_distinct
# Out:
# 422465 2424
#       index flightnumber        date              filename  \
# 0      3261     DLH9922   2023-04-01  2023.04.01-051111.db
# 1      3262          N/A  2023-04-01  2023.04.01-051111.db
# 2      3263          N/A  2023-04-01  2023.04.01-051111.db
# 3      3264     CSN312    2023-04-01  2023.04.01-051111.db
# 4      3265     DLH491    2023-04-01  2023.04.01-051111.db
# ...     ...          ...         ...                   ...
# 2419   5047     CFG2092   2023-07-31  2023.07.31-235039.db
# 2420   5048     DLH476    2023-07-31  2023.07.31-235039.db
# 2421   5049     SAS935    2023-07-31  2023.07.31-235039.db
# 2422   5050     CPA841    2023-07-31  2023.07.31-235039.db
# 2423   5051     DLH458    2023-07-31  2023.07.31-235039.db
#
#                          mintime                     maxtime  \
# 0     2023-04-01 00:42:32.100000  2023-04-01 01:01:07.500000
# 1     2023-04-01 00:59:37.100000  2023-04-01 03:40:13.900000
# 2     2023-04-01 05:21:28.400000  2023-04-01 18:48:53.900000
# 3     2023-04-01 02:49:29.100000  2023-04-01 03:05:38.800000
# 4     2023-04-01 03:20:48.200000  2023-04-01 03:40:39.000000
# ...                          ...                         ...
# 2419  2023-07-31 17:46:17.800000  2023-07-31 18:02:17.500000
# 2420  2023-07-31 18:10:19.800000  2023-07-31 18:26:09.400000
# 2421  2023-07-31 18:14:31.000000  2023-07-31 18:31:05.900000
# 2422  2023-07-31 18:43:24.500000  2023-07-31 19:02:04.900000
# 2423  2023-07-31 18:55:17.900000  2023-07-31 19:11:52.800000
#
#                     min_r                min_z                theta
# 0      33.100000000000001   10.800000000000001   15.000000000000000
# 1      99.900000000000006    7.800000000000000   52.000000000000000
# 2      89.900000000000006    7.200000000000000   57.000000000000000
# 3      72.799999999999997    7.700000000000000   49.000000000000000
# 4      32.899999999999999   10.100000000000000   15.000000000000000
# ...                   ...                  ...                  ...
# 2419   72.400000000000006    9.199999999999999   10.000000000000000
# 2420   32.899999999999999   10.100000000000000   15.000000000000000
# 2421   35.899999999999999    8.600000000000000   15.000000000000000
# 2422   54.899999999999999    9.199999999999999   55.000000000000000
# 2423   72.500000000000000    9.800000000000001   10.000000000000000
#
# [2424 rows x 9 columns]

# %%
'''con = sqlite3.connect('./header_files_for_time_range/header_2023')

temp_df = pd.read_sql_query(f'Select * from all_triggers_2023_04 where lt_triggers = 1', con)

con.close()
print(len(temp_df))'''

temp_df = pd.DataFrame()
con = sqlite3.connect('./header_files_for_time_range/header_2023')
for table in ['all_triggers_2023_04', 'all_triggers_2023_05', 'all_triggers_2023_06', 'all_triggers_2023_07']:
    temp = pd.read_sql_query(f'Select * From {table} where radiant_triggers = 1', con)
    if(len(temp_df == 0)):
        temp_df = temp
    else:
        temp_df = pd.concat([temp_df, temp], ignore_index=True, sort=False)
con.close()
temp_df
# Out:
#            index  station_number  run_number  event_number  \
# 0              3              11        2700          2857
# 1              5              11        2700          2859
# 2              8              11        2700          2862
# 3             13              11        2700          2867
# 4             23              11        2700          2877
# ...          ...             ...         ...           ...
# 1765331  6788148              24        2030            89
# 1765332  6788157              24        2030            98
# 1765333  6788197              24        2030           138
# 1765334  6788208              24        2030           149
# 1765335  6788215              24        2030           156
#
#                          trigger_time  radiant_triggers  lt_triggers  \
# 0       1,688,205,008.839688062667847                 1            0
# 1       1,688,205,012.186495542526245                 1            0
# 2       1,688,205,020.579510688781738                 1            0
# 3       1,688,205,035.797134876251221                 1            0
# 4       1,688,205,055.516614437103271                 1            0
# ...                               ...               ...          ...
# 1765331 1,690,830,478.144085645675659                 1            0
# 1765332 1,690,830,507.275148391723633                 1            0
# 1765333 1,690,830,576.762142181396484                 1            0
# 1765334 1,690,830,602.926198482513428                 1            0
# 1765335 1,690,830,619.647583723068237                 1            0
#
#          force_triggers
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 1765331               0
# 1765332               0
# 1765333               0
# 1765334               0
# 1765335               0
#
# [1765336 rows x 8 columns]

# %%
# add fk_date_flightnumber
flights_distinct = tracker.flights_distinct
flights_distinct = sqldf(''' 
SELECT
    *
    ,date || '_' || flightnumber as fk_date_flightnumber
FROM flights_distinct
''')
flights = tracker.flights
flights = sqldf(''' 
SELECT
    *
    ,date(readtime) || '_' || flightnumber as fk_date_flightnumber
FROM flights
''')


flights_distinct['mintime'] = pd.to_datetime(flights_distinct.mintime).dt.tz_localize('UTC')
flights_distinct['maxtime'] = pd.to_datetime(flights_distinct.maxtime).dt.tz_localize('UTC')

flights_distinct['mintime_millis'] = flights_distinct.mintime.astype(np.int64) // 10 ** 6
flights_distinct['maxtime_millis'] = flights_distinct.maxtime.astype(np.int64) // 10 ** 6

flights_distinct['mintime_sec'] = flights_distinct.mintime.astype(np.int64) // 10 ** 9
flights_distinct['maxtime_sec'] = flights_distinct.maxtime.astype(np.int64) // 10 ** 9

flights_distinct['ID'] = flights_distinct.index

temp_df['trigger_time_millis'] = (temp_df['trigger_time'] * (10 ** 3)).astype(np.int64)
temp_df['trigger_time_sec'] = (temp_df['trigger_time']).astype(np.int64)

flights_distinct
# Out:
#       index flightnumber        date              filename  \
# 0      3261     DLH9922   2023-04-01  2023.04.01-051111.db
# 1      3262          N/A  2023-04-01  2023.04.01-051111.db
# 2      3263          N/A  2023-04-01  2023.04.01-051111.db
# 3      3264     CSN312    2023-04-01  2023.04.01-051111.db
# 4      3265     DLH491    2023-04-01  2023.04.01-051111.db
fk_timestamp
# Out:
#           trigger_time_sec
# 0               1680309752
# 1               1680309753
# 2               1680309754
# 3               1680309755
# 4               1680309756
# ...                    ...
# 10520955        1690830707
# 10520956        1690830708
# 10520957        1690830709
# 10520958        1690830710
# 10520959        1690830711
#
# [10520960 rows x 1 columns]

# %%
query = ''' 
SELECT
    count(trigger_time_sec) as sum_triggers_per_second
    --,station_number
    ,trigger_time_sec
    --,CASE 
    --    WHEN force_triggers = 1 THEN 1
    --    WHEN lt_triggers = 1 THEN 2
    --    WHEN radiant_triggers = 1 THEN 3
    --    ELSE -1
    --END AS trigger_type
    --,force_triggers
    --,lt_triggers
    --,radiant_triggers
    --,trigger_time_millis
FROM temp_df
--GROUP BY station_number, trigger_time_sec

GROUP BY trigger_time_sec
'''

test = sqldf(query)
test
# Out:
#         sum_triggers_per_second  trigger_time_sec
# 0                             1        1688205000
# 1                             2        1688205001
# 2                             1        1688205003
# 3                             1        1688205005
# 4                             2        1688205007
# ...                         ...               ...
# 508367                        1        1690830696
# 508368                        1        1690830697
# 508369                        1        1690830702
# 508370                        1        1690830706
# 508371                        1        1690830711
#
# [508372 rows x 2 columns]

# %%
fk_timestamp = fk_timestamp.merge(test, on=['trigger_time_sec'], how='left')

# %%
fk_timestamp
# Out:
#           trigger_time_sec  sum_triggers_per_second
# 0               1680309752                      NaN
# 1               1680309753                      NaN
# 2               1680309754                      NaN
# 3               1680309755                      NaN
# 4               1680309756                      NaN
# ...                    ...                      ...
# 10520955        1690830707                      NaN
# 10520956        1690830708                      NaN
# 10520957        1690830709                      NaN
# 10520958        1690830710                      NaN
# 10520959        1690830711        1.000000000000000
#
# [10520960 rows x 2 columns]

# %%
fk_timestamp.sum_triggers_per_second.fillna(0, inplace = True)
#fk_timestamp.station_number.fillna(-1, inplace=True)
#fk_timestamp.force_triggers.fillna(-1, inplace=True)

# %%
fk_timestamp
# Out:
#           trigger_time_sec  sum_triggers_per_second
# 0               1680309752        0.000000000000000
# 1               1680309753        0.000000000000000
# 2               1680309754        0.000000000000000
# 3               1680309755        0.000000000000000
# 4               1680309756        0.000000000000000
# ...                    ...                      ...
# 10520955        1690830707        0.000000000000000
# 10520956        1690830708        0.000000000000000
# 10520957        1690830709        0.000000000000000
# 10520958        1690830710        0.000000000000000
# 10520959        1690830711        1.000000000000000
#
# [10520960 rows x 2 columns]

# %%
fk_timestamp['sum_triggers_per_second'] = fk_timestamp.sum_triggers_per_second.astype('uint16')

# %%
# join header information on flights_distinct
query = '''
SELECT 
    flightnumber
    ,fk_date_flightnumber
    --,station_number
    ,sum_triggers_per_second
    ,trigger_time_sec
FROM flights_distinct
LEFT JOIN ( 
            SELECT
                *
            FROM fk_timestamp
)t0

ON t0.trigger_time_sec > flights_distinct.mintime_sec
AND t0.trigger_time_sec < flights_distinct.maxtime_sec
WHERE trigger_time_sec is not null
and min_r < 50
--AND force_triggers = 0
--AND lt_triggers = 1
--AND radiant_triggers = 1
--GROUP BY fk_date_flightnumber, station_number, trigger_time_sec
GROUP BY fk_date_flightnumber, trigger_time_sec
'''

result = sqldf(query)
clear_output(wait=True)
result
# Out:
#         flightnumber fk_date_flightnumber  sum_triggers_per_second  \
# 0           CPA095    2023-04-01_CPA095                          0
# 1           CPA095    2023-04-01_CPA095                          0
# 2           CPA095    2023-04-01_CPA095                          0
# 3           CPA095    2023-04-01_CPA095                          0
# 4           CPA095    2023-04-01_CPA095                          0
# ...              ...                  ...                      ...
# 2165558     SWR38J    2023-07-31_SWR38J                          0
# 2165559     SWR38J    2023-07-31_SWR38J                          0
# 2165560     SWR38J    2023-07-31_SWR38J                          0
# 2165561     SWR38J    2023-07-31_SWR38J                          3
# 2165562     SWR38J    2023-07-31_SWR38J                          0
#
#          trigger_time_sec
# 0              1680338251
# 1              1680338252
# 2              1680338253
# 3              1680338254
# 4              1680338255
# ...                   ...
# 2165558        1690821694
# 2165559        1690821695
# 2165560        1690821696
# 2165561        1690821697
# 2165562        1690821698
#
# [2165563 rows x 4 columns]

# %%
sqldf('Select count(trigger_time_sec) as count, trigger_time_sec, GROUP_CONCAT(flightnumber ) AS flightnumbers  from result group By trigger_time_sec order by count desc')
# Out:
#          count  trigger_time_sec  \
# 0            6        1684593656
# 1            6        1684593655
# 2            6        1684593654
# 3            6        1684593653
# 4            6        1684593652
# ...        ...               ...
# 1714719      1        1680309757
# 1714720      1        1680309756
# 1714721      1        1680309755
# 1714722      1        1680309754
# 1714723      1        1680309753
#
#                                             flightnumbers
# 0        DLH452  ,KLM603  ,KLM677  ,N/A,SKIER62 ,SVA041
# 1        DLH452  ,KLM603  ,KLM677  ,N/A,SKIER62 ,SVA041
# 2        DLH452  ,KLM603  ,KLM677  ,N/A,SKIER62 ,SVA041
# 3        DLH452  ,KLM603  ,KLM677  ,N/A,SKIER62 ,SVA041
# 4        DLH452  ,KLM603  ,KLM677  ,N/A,SKIER62 ,SVA041
# ...                                                   ...
# 1714719                                          DLH9922
# 1714720                                          DLH9922
# 1714721                                          DLH9922
# 1714722                                          DLH9922
# 1714723                                          DLH9922
#
# [1714724 rows x 3 columns]

# %%
query = '''
SELECT 
    *
FROM (
    SELECT count(trigger_time_sec) as count
    ,trigger_time_sec
    FROM result
    GROUP BY trigger_time_sec
)t0
WHERE count > 1
ORDER BY trigger_time_sec

'''

timestamps_to_exclude = sqldf(query)
timestamps_to_exclude
# Out:
#         count  trigger_time_sec
# 0           2        1680461028
# 1           2        1680461029
# 2           2        1680461030
# 3           2        1680461031
# 4           2        1680461032
# ...       ...               ...
# 371207      2        1690827964
# 371208      2        1690827965
# 371209      2        1690827966
# 371210      2        1690827967
# 371211      2        1690827968
#
# [371212 rows x 2 columns]

# %%
result = result[~result['trigger_time_sec'].isin(timestamps_to_exclude['trigger_time_sec'])]
result = result[~result['flightnumber'].str.contains('SKI', na=False)]
result = result[~result['flightnumber'].str.contains('RCH108', na=False)]
result = result[~result['flightnumber'].str.contains('N/A', na=False)]
result
# Out:
#         flightnumber fk_date_flightnumber  sum_triggers_per_second  \
# 0           CPA095    2023-04-01_CPA095                          0
# 1           CPA095    2023-04-01_CPA095                          0
# 2           CPA095    2023-04-01_CPA095                          0
# 3           CPA095    2023-04-01_CPA095                          0
# 4           CPA095    2023-04-01_CPA095                          0
# ...              ...                  ...                      ...
# 2165558     SWR38J    2023-07-31_SWR38J                          0
# 2165559     SWR38J    2023-07-31_SWR38J                          0
# 2165560     SWR38J    2023-07-31_SWR38J                          0
# 2165561     SWR38J    2023-07-31_SWR38J                          3
# 2165562     SWR38J    2023-07-31_SWR38J                          0
#
#          trigger_time_sec
# 0              1680338251
# 1              1680338252
# 2              1680338253
# 3              1680338254
# 4              1680338255
# ...                   ...
# 2165558        1690821694
# 2165559        1690821695
# 2165560        1690821696
# 2165561        1690821697
# 2165562        1690821698
#
# [656885 rows x 4 columns]

# %%
distinct_fk_date_flightnumber = sqldf("Select distinct fk_date_flightnumber from result")

# %%
#-------------------------------------------------------------------------------------------------------------------
def part_lin(x, times, r):
    return_linspace = []
    for element in x:
        #print()
        #print(times, element)
        #print(np.where(times <= element))
        #print()
        index = np.where(times <= element)[0][-1]
        if index >= (len(times) - 1):
            index = index - 1
            print(f'Index {index} out of range {len(times) - 1}')
        y2 = r.iloc[index+1]
        y1 = r.iloc[index]
        x2 = times.iloc[index+1]
        x1 = times.iloc[index]
        m = (y2 - y1) / (x2 - x1)
        t = y2 - m * x2
        return_linspace.append(m*element+t)
    len_ret = len(return_linspace)
    len_x = len(x)
    while(len_ret < len_x):
        return_linspace.append(0)

    return return_linspace

# %%
result_df = pd.DataFrame()
length = len(distinct_fk_date_flightnumber)

for i in range(length):
    clear_output(wait=True)
    #----------------------------------------------------------
    fk_date_flightnumber = distinct_fk_date_flightnumber.fk_date_flightnumber.iloc[i]
    print(fk_date_flightnumber, ', ', i, ':', length)

    #----------------------------------------------------------   
    flights_temp = flights[flights.fk_date_flightnumber == fk_date_flightnumber]
    
    times = pd.to_datetime(flights_temp.readtime_utc, format='ISO8601').astype('int64') / 10**9
    r = np.sqrt(flights_temp.r2)
    trigger_times = result[result.fk_date_flightnumber == fk_date_flightnumber].trigger_time_sec

    if((len(trigger_times) == 0) | len(times) == 0):
        print('len trigger_times = 0 or flightnunber == N/A or len(times) == 0')
        continue
    
    temp_table = pd.DataFrame(result[result.fk_date_flightnumber == fk_date_flightnumber].copy())
    print(f'flightnumber: {fk_date_flightnumber}')

    #print('--------------------------------------------')
    #print(times.min(), '<', trigger_times.min())
    #print(trigger_times.max(), '<', times.max())
    #print('--------------------------------------------')

    temp_table['d'] = part_lin(trigger_times, times, r)
    if(len(temp_table)):
        result_df = pd.concat([result_df, temp_table], ignore_index=True, sort=False)

result_df
# Out:
# 2023-07-31_SWR38J   ,  674 : 675
# flightnumber: 2023-07-31_SWR38J
#        flightnumber fk_date_flightnumber  sum_triggers_per_second  \
# 0          CPA095    2023-04-01_CPA095                          0
# 1          CPA095    2023-04-01_CPA095                          0
# 2          CPA095    2023-04-01_CPA095                          0
# 3          CPA095    2023-04-01_CPA095                          0
# 4          CPA095    2023-04-01_CPA095                          0
# ...             ...                  ...                      ...
# 656880     SWR38J    2023-07-31_SWR38J                          0
# 656881     SWR38J    2023-07-31_SWR38J                          0
# 656882     SWR38J    2023-07-31_SWR38J                          0
# 656883     SWR38J    2023-07-31_SWR38J                          3
# 656884     SWR38J    2023-07-31_SWR38J                          0
#
#         trigger_time_sec                    d
# 0             1680338251  149.553518950939178
# 1             1680338252  149.244452536106110
# 2             1680338253  148.935386061668396
# 3             1680338254  148.626319587230682
# 4             1680338255  148.317253112792969
# ...                  ...                  ...
# 656880        1690821694  147.745755314826965
# 656881        1690821695  147.982259809970856
# 656882        1690821696  148.218764305114746
# 656883        1690821697  148.455268859863281
# 656884        1690821698  148.691773355007172
#
# [656885 rows x 5 columns]

# %%
from matplotlib.ticker import MaxNLocator
test = sqldf('Select avg(sum_triggers_per_second) as avg_triggers_per_sec, round(d, 0) as d from result_df group by round(d, 0)')
plt.figure(figsize =(20, 8) ) 
plt.plot(test.d, test.avg_triggers_per_sec, 'x--')
plt.title('avg trigger_rate over d (radiant_triggers) (2023_04 - 2023_07)')
plt.xlabel('d [km]')
plt.ylabel('avg trigger rate')
plt.gca().xaxis.set_major_locator(MaxNLocator(20))

# %%
plt.hist(result_df.d, bins = 50)
plt.title('distance (d) distribution present in plot')
plt.xlabel('d [km]')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
was_ueber_ist = sqldf("Select distinct fk_date_flightnumber from result_df")

# %%
min_z = sqldf("Select fk_date_flightnumber, min_z from flights_distinct order by min_z asc")
min_z = min_z[min_z['fk_date_flightnumber'].isin(was_ueber_ist['fk_date_flightnumber'])]
min_z
# Out:
#      fk_date_flightnumber                min_z
# 78    2023-05-30_HFM313      6.800000000000000
# 79    2023-06-13_HFM813      6.800000000000000
# 114   2023-04-16_CES208      7.700000000000000
# 125   2023-05-29_UAE93Q      7.700000000000000
# 126   2023-06-10_AIC126      7.700000000000000
# ...                   ...                  ...
# 2410  2023-06-07_QQE580     11.400000000000000
# 2413  2023-06-29_QQE252     11.400000000000000
# 2414  2023-06-30_CFMHL      11.400000000000000
# 2420  2023-07-18_VJT794     12.000000000000000
# 2423  2023-04-11_GDSMR      12.600000000000000
#
# [678 rows x 2 columns]

# %%
test = FlightTracker("2023-07-13 00:00:00", "2023-07-14 00:00:00")
test.flights_distinct
# Out:
#     index flightnumber        date              filename  \
# 0       0          N/A  2023-07-13  2023.07.13-234909.db
# 1       1     ELY005    2023-07-13  2023.07.13-234909.db
# 2       2     QTR65R    2023-07-13  2023.07.13-234909.db
# 3       3     THY8JK    2023-07-13  2023.07.13-234909.db
# 4       4     CPA843    2023-07-13  2023.07.13-234909.db
# 5       5     AFR163    2023-07-13  2023.07.13-234909.db
# 6       6     DLH490    2023-07-13  2023.07.13-234909.db
# 7       7     SKIER41   2023-07-13  2023.07.13-234909.db
# 8       8     EDW10K    2023-07-13  2023.07.13-234909.db
# 9       9     RCH108    2023-07-13  2023.07.13-234909.db
# 10     10     SAS935    2023-07-13  2023.07.13-234909.db
# 11     11     CPA841    2023-07-13  2023.07.13-234909.db
# 12     12     DLH476    2023-07-13  2023.07.13-234909.db
# 13     13     NCA004    2023-07-13  2023.07.13-234909.db
#
#                        mintime                     maxtime  \
# 0   2023-07-13 05:26:46.600000  2023-07-13 17:19:14.500000
# 1   2023-07-13 05:26:56.700000  2023-07-13 05:42:26.200000
# 2   2023-07-13 06:00:26.500000  2023-07-13 06:16:56.300000
# 3   2023-07-13 07:20:14.700000  2023-07-13 07:36:04.300000
# 4   2023-07-13 10:21:52.700000  2023-07-13 10:38:37.600000
# 5   2023-07-13 10:40:58.300000  2023-07-13 10:56:47.900000
# 6   2023-07-13 13:01:19.200000  2023-07-13 13:09:51.700000
# 7   2023-07-13 14:18:31.700000  2023-07-13 18:07:43.600000
# 8   2023-07-13 16:01:51.900000  2023-07-13 16:19:47.100000
# 9   2023-07-13 16:19:47.100000  2023-07-13 19:13:42.800000
# 10  2023-07-13 18:04:07.500000  2023-07-13 18:21:57.700000
# 11  2023-07-13 18:29:50.000000  2023-07-13 18:46:34.900000
# 12  2023-07-13 18:42:33.800000  2023-07-13 19:01:59.400000
# 13  2023-07-13 22:03:42.400000  2023-07-13 22:16:41.200000
#
#                   min_r                min_z                theta
# 0     0.700000000000000    0.000000000000000   24.000000000000000
# 1    65.799999999999997    9.199999999999999    2.000000000000000
# 2    32.200000000000003    8.300000000000001   18.000000000000000
# 3    74.299999999999997    9.500000000000000    7.000000000000000
# 4    70.500000000000000    9.500000000000000   49.000000000000000
# 5    13.900000000000000    8.900000000000000   50.000000000000000
# 6   136.800000000000011    9.500000000000000   18.000000000000000
# 7     0.600000000000000    0.000000000000000   47.000000000000000
# 8    70.700000000000003    9.800000000000001   10.000000000000000
# 9     0.600000000000000    0.000000000000000   47.000000000000000
# 10   68.700000000000003    9.600000000000000   10.000000000000000
# 11   70.400000000000006    8.900000000000000   49.000000000000000
# 12   40.100000000000001    9.800000000000001   10.000000000000000
# 13  112.400000000000006    8.900000000000000   31.000000000000000

# %%
f = test.get_flight_by_index(9, filetype='headers.root')
f.plot_flight()
# Out:
# INFO:runtable_database:database connection to RNOG_live established

# %%
sqldf("Select * from was_ueber_ist where fk_date_flightnumber like '%RCH%' ")
# Out:
#   fk_date_flightnumber
# 0  2023-06-18_RCH310

# %%
test = FlightTracker("2023-06-18 00:00:00")
test.flights_distinct
# Out:
#     index flightnumber        date              filename  \
# 0       0     AFR293    2023-06-18  2023.06.18-025627.db
# 1       1          N/A  2023-06-18  2023.06.18-025627.db
# 2       2          N/A  2023-06-18  2023.06.18-025627.db
# 3       3     CPA843    2023-06-18  2023.06.19-025631.db
# 4       4          N/A  2023-06-18  2023.06.19-025631.db
# 5       5          N/A  2023-06-18  2023.06.19-025631.db
# 6       6     DAL143    2023-06-18  2023.06.19-025631.db
# 7       7     DAL179    2023-06-18  2023.06.19-025631.db
# 8       8     OCN72     2023-06-18  2023.06.19-025631.db
# 9       9     DLH490    2023-06-18  2023.06.19-025631.db
# 10     10     AFR374    2023-06-18  2023.06.19-025631.db
# 11     11     NCA062    2023-06-18  2023.06.19-025631.db
# 12     12     SKIER41   2023-06-18  2023.06.19-025631.db
# 13     13     KLM677    2023-06-18  2023.06.19-025631.db
# 14     14     EDW10K    2023-06-18  2023.06.19-025631.db
# 15     15     DAL145    2023-06-18  2023.06.19-025631.db
# 16     16     EDW14L    2023-06-18  2023.06.19-025631.db
# 17     17     THY79K    2023-06-18  2023.06.19-025631.db
# 18     18     RCH310    2023-06-18  2023.06.19-025631.db
# 19     19     DLH476    2023-06-18  2023.06.19-025631.db
# 20     20     SAS935    2023-06-18  2023.06.19-025631.db
